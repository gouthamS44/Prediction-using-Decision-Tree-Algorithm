# %% [markdown]
# #  GRIP-TSF-Task #6: Prediction using Decision Tree Algorithm

# %% [markdown]
# ## Coded by - Goutham M

# %% [markdown]
# In this task, Creating the Decision Tree classifier and visualize it graphically.The classification technique is a systematic approach to build classification models from an input dat set.Decision Tree Classifier is a simple and widely used classification technique. It applies a straitforward idea to solve the classification problem.
#
# Decision Tree Classifier poses a series of carefully crafted questions about the attributes of the test record. Each time time it receive an answer, a follow-up question is asked until a conclusion about the calss label of the record is reached.The purpose of this is to find when we feed any new data to this classifier, it would be able to
# predict the right class accordingly.

# %%
# Import all required libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset 
from sklearn.datasets import load_iris
data = load_iris()
iris_data = pd.DataFrame(dat.data,columns = dat.feature_names)
dat = data.target

# %%
#Prints all the data
iris_data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#prints all the column headings
iris_data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#(row,column)
dat.shape
# Out:
# (150,)

# %%
#Returns sum of all null values present in the variable
iris_data.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
# Plotting the histogram of the given dataset 
iris_data.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000016B01B69EB0>,
# ...
#       dtype=object)

# %%
# Pairplot of the given data
sns.pairplot(iris_data)

# %%
#Now,Let's Build the Model.
x = iris_data
y = dat
from sklearn .model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)
#returns (number of row, number of column) for each training and test data.
print("Shape of feature training data :",x_train.shape)
print("Shape of target training data :",y_train.shape)
print("Shape of feature test data :",x_test.shape)
print("Shape of target test data :",y_test.shape)
# Out:
# Shape of feature training data : (105, 4)
# Shape of target training data : (105,)
# Shape of feature test data : (45, 4)
# Shape of target test data : (45,)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix

clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Finding accuracy for training data
predict = clf.predict(x_train)
print("Accuracy of training data : ",accuracy_score(predict,y_train)*100,"%")
print("Confusin matrix of training data :'\n' ",confusion_matrix(predict,y_train))
sns.heatmap(confusion_matrix(predict,y_train),annot = True,cmap = 'Greens')
# Out:
# Accuracy of training data :  100.0 %
# Confusin matrix of training data :'
# '  [[31  0  0]
#  [ 0 37  0]
#  [ 0  0 37]]

# %%
plt.figure(figsize  = (18,18))
tree.plot_tree(clf,filled = True,rounded = True,proportion = True,node_ids = True , feature_names = data.feature_names)
plt.show()

# %% [markdown]
# ##                                           Thank you!
